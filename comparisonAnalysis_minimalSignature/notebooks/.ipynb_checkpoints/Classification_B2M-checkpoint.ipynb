# %%
library(readxl)
library(caret)
library(glmnet)
library(ggplotify)
library(randomForest)
# Out:
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: ‘randomForest’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin

# %%
## Read excel 
became = data.frame(t(read_xlsx('../data/BECAME1_LipidomicData_lipidesidentifiés.xlsx',sheet=1)))

## Remove the first 10 columns (not lipids)
became_num = became[-c(1:10),]

## Cast data to numeric type 
rownames(became_num) = paste0('X',rownames(became_num))
for(i in 1:ncol(became_num)){became_num[,i]=as.numeric(became_num[,i])}

# %%
meta = read.csv('../data/merged_dataset_meta.csv')
response_name = 'cluster'

## Subset only the patients from the BECAME cohort
became_data = became_num[rownames(subset(meta,cohort=='BECAME' & group=='HFpEF')),]
became_data = data.frame(scale(log(became_data[,grepl('^X',colnames(became_data))])))

# %%
cor_matrix <- cor(became_data)

# Find indices of highly correlated pairs (excluding the diagonal)
high_corr_indices <- which(abs(cor_matrix) > 0.8 & lower.tri(cor_matrix), arr.ind = TRUE)

# Create a vector to hold whether to keep a feature or not
keep_feature <- rep(TRUE, ncol(became_data))

# Loop over each pair and decide which feature to exclude
for (index in seq_len(nrow(high_corr_indices))) {
    i <- high_corr_indices[index, "row"]
    j <- high_corr_indices[index, "col"]
    
    # You need a strategy to decide which feature to remove, e.g., keep the one that
    # has the fewer high correlations overall, or keep the one that comes first.
    # This example simply removes the second feature in the pair.
    
    keep_feature[j] <- FALSE
}

# Select the columns to keep and create a new dataframe
df_uncorrelated <- became_data[, keep_feature, drop = FALSE]

# View the remaining features in the dataframe
# print(names(df_uncorrelated))

# %%
options(repr.plot.width = 12, repr.plot.height = 5)

p1 = as.ggplot(pheatmap::pheatmap(cor(became_data),border_col='white',clustering_method='ward.D',silent=T))
p2 = as.ggplot(pheatmap::pheatmap(cor(df_uncorrelated),border_col='white',clustering_method='ward.D',silent=T))

cowplot::plot_grid(p1,p2)
# Out:
# plot without title

# %%
## Subset the metadata 

## Log transform the intensities 
became_data$response_var = as.factor(as.numeric(meta[rownames(became_data),response_name]=='B1'))

## Create train/test indices 
index <- createDataPartition(became_data$response_var, p = 0.7, list = FALSE)

## Define training data 
became_data_train = became_data[index,]

# %%
options(warn = -1)
lipids = colnames(became_data)[grepl('^X',colnames(became_data))]

# Create a formula for the null model
null_model_formula <- as.formula(paste("response_var ~ 1"))
# Create a formula for lipids
lipids_formula <- as.formula(paste("response_var ~", paste(lipids, collapse = " + ")))

# Step 2: Forward-backward feature selection with BIC on lipids
null_model <- glm(null_model_formula, data = became_data_train, family = 'binomial')
lipids_model <- step(null_model, direction = "both", 
                     scope = list(lower = null_model_formula, 
                                  upper = lipids_formula), 
                     k = log(nrow(became_data_train)),trace = FALSE) 


predictions_became <- predict(lipids_model, newdata =  became_data[-index,], type = "response")

# %%
summary(lipids_model)
# Out:
# Call:
# glm(formula = response_var ~ X93 + X229 + X32 + X14, family = "binomial",
#     data = became_data_train)
#
# Deviance Residuals:
#        Min          1Q      Median          3Q         Max
# -3.322e-04  -2.000e-08  -2.000e-08  -1.000e-08   3.391e-04
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)   -697.5    60750.8  -0.011    0.991
# X93          -1026.5    89033.5  -0.012    0.991
# X229          -658.6    57762.9  -0.011    0.991
# X32           -301.8    29110.5  -0.010    0.992
# X14           -213.3    20641.3  -0.010    0.992
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 8.0976e+01  on 71  degrees of freedom
# Residual deviance: 3.5136e-07  on 67  degrees of freedom
# AIC: 10
#
# Number of Fisher Scoring iterations: 25

# %%
confusionMatrix(became_data[-index,]$response_var,as.factor(round(predictions_became)))
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  0  1
#          0 19  4
#          1  0  7
#
#                Accuracy : 0.8667
#                  95% CI : (0.6928, 0.9624)
#     No Information Rate : 0.6333
#     P-Value [Acc > NIR] : 0.004512
#
#                   Kappa : 0.6891
#
#  Mcnemar's Test P-Value : 0.133614
#
#             Sensitivity : 1.0000
#             Specificity : 0.6364
#          Pos Pred Value : 0.8261
#          Neg Pred Value : 1.0000
#              Prevalence : 0.6333
#          Detection Rate : 0.6333
#    Detection Prevalence : 0.7667
#       Balanced Accuracy : 0.8182
#
#        'Positive' Class : 0

# %%
x = became_data[index,grepl('^X',colnames(became_data))]
y = became_data[index,]$response_var
cv_model <- cv.glmnet(as.matrix(x), y, alpha = 1,family='binomial')

lambda_min <- cv_model$lambda.min
lambda_1se <- cv_model$lambda.1se

min_model <- glmnet(as.matrix(x), y, alpha = 1, lambda = lambda_min, family='binomial')
co = coef(min_model)[,1]
lambda_min_predictors = names(co[abs(co)>0])

se_model <- glmnet(as.matrix(x), y, alpha = 1, lambda = lambda_1se, family='binomial')
co = coef(se_model)[,1]
lambda_se_predictors = names(co[abs(co)>0])

# %%
preds =  predict(se_model, s = lambda_1se, newx = as.matrix(became_data[-index,grepl('^X',colnames(became_data))]),type='response')
confusionMatrix(became_data[-index,]$response_var,as.factor(round(preds)))
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  0  1
#          0 22  1
#          1  2  5
#
#                Accuracy : 0.9
#                  95% CI : (0.7347, 0.9789)
#     No Information Rate : 0.8
#     P-Value [Acc > NIR] : 0.1227
#
#                   Kappa : 0.7059
#
#  Mcnemar's Test P-Value : 1.0000
#
#             Sensitivity : 0.9167
#             Specificity : 0.8333
#          Pos Pred Value : 0.9565
#          Neg Pred Value : 0.7143
#              Prevalence : 0.8000
#          Detection Rate : 0.7333
#    Detection Prevalence : 0.7667
#       Balanced Accuracy : 0.8750
#
#        'Positive' Class : 0

# %%
preds =  predict(min_model, s = lambda_1se, newx = as.matrix(became_data[-index,grepl('^X',colnames(became_data))]),type='response')
confusionMatrix(became_data[-index,]$response_var,as.factor(round(preds)))
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  0  1
#          0 21  2
#          1  2  5
#
#                Accuracy : 0.8667
#                  95% CI : (0.6928, 0.9624)
#     No Information Rate : 0.7667
#     P-Value [Acc > NIR] : 0.1381
#
#                   Kappa : 0.6273
#
#  Mcnemar's Test P-Value : 1.0000
#
#             Sensitivity : 0.9130
#             Specificity : 0.7143
#          Pos Pred Value : 0.9130
#          Neg Pred Value : 0.7143
#              Prevalence : 0.7667
#          Detection Rate : 0.7000
#    Detection Prevalence : 0.7667
#       Balanced Accuracy : 0.8137
#
#        'Positive' Class : 0

# %%
lambda_min_predictors
# Out:
#  [1] "(Intercept)" "X48"         "X56"         "X87"         "X92"
#  [6] "X94"         "X97"         "X112"        "X122"        "X127"
# [11] "X129"        "X141"        "X149"        "X158"        "X160"
# [16] "X161"        "X166"        "X167"        "X186"        "X197"
# [21] "X213"        "X214"

# %%
# Train the Random Forest model
rfModel <- randomForest(response_var ~ ., data = became_data[index,], ntree = 500)


# Use RFE to find the best subset of features
controlRF <- rfeControl(
  functions = rfFuncs,  # Random Forest model functions
  method = "repeatedcv",  # Cross-validation
  repeats = 5,  # Number of repeats for cross-validation
  verbose = FALSE
)

rfeModel <- rfe(
  x = became_data[index, -ncol(became_data)],  # Exclude the response variable
  y = became_data[index, ]$response_var,
  sizes = c(1:(ncol(became_data)-1)),  # Range of feature subset sizes to consider
  rfeControl = controlRF
)

# The optimal number of features
optimalFeatures <- predictors(rfeModel)
print(optimalFeatures)

# %%
# Final Random Forest Model based on optimal features
optimalModel <- randomForest(response_var ~ ., data = became_data[index, c(optimalFeatures, "response_var")], ntree = 500)

# Evaluate the final model on the test set
predictions <- predict(optimalModel, became_data[-index,])
confusionMatrix(predictions, became_data[-index,]$response_var)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  0  1
#          0 23  2
#          1  0  5
#
#                Accuracy : 0.9333
#                  95% CI : (0.7793, 0.9918)
#     No Information Rate : 0.7667
#     P-Value [Acc > NIR] : 0.01741
#
#                   Kappa : 0.7931
#
#  Mcnemar's Test P-Value : 0.47950
#
#             Sensitivity : 1.0000
#             Specificity : 0.7143
#          Pos Pred Value : 0.9200
#          Neg Pred Value : 1.0000
#              Prevalence : 0.7667
#          Detection Rate : 0.7667
#    Detection Prevalence : 0.8333
#       Balanced Accuracy : 0.8571
#
#        'Positive' Class : 0
