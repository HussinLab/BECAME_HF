# %%
library(igraph)
# Out:
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
scaled_df = read.csv('../data/merged_dataset.csv')
meta = read.csv('../data/merged_dataset_meta.csv')

# %%
options(repr.plot.width = 7, repr.plot.height = 6)

mat <- cor(scaled_df)
pheatmap::pheatmap(mat)
# Out:
# plot without title

# %%
nlevels(as.factor(importance$lipid_class))
# Out:
# [1] 15

# %%
data(mtcars)

# %%
# Map the color to cylinders
my_color <- coul[as.numeric(as.factor(importance[rownames(mat),'lipid_class']))]

# %%
coul
# Out:
# [1] "#66C2A5" "#FC8D62" "#8DA0CB"

# %%
importance[rownames(mat),'lipid_class']
# Out:
#   [1] "Acylcarnitines"                   "Acylcarnitines"
#   [3] "Acylcarnitines"                   "Acylcarnitines"
#   [5] "Ceramides"                        "Ceramides"
#   [7] "Cholesteryl esters"               "Cholesteryl esters"
#   [9] "Cholesteryl esters"               "Cholesteryl esters"
#  [11] "Cholesteryl esters"               "Lysophosphatidylcholine ethers"
#  [13] "Lysophosphatidylcholine ethers"   "Lysophosphatidylcholine ethers"
#  [15] "Lysophosphatidylcholine ethers"   "Lysophosphatidylcholines"
#  [17] "Lysophosphatidylcholines"         "Lysophosphatidylcholines"
#  [19] "Lysophosphatidylcholines"         "Lysophosphatidylcholines"
#  [21] "Lysophosphatidylcholines"         "Lysophosphatidylcholines"
#  [23] "Lysophosphatidylcholines"         "Lysophosphatidylcholines"
#  [25] "Lysophosphatidylcholines"         "Lysophosphatidylcholines"
#  [27] "Lysophosphatidylcholines"         "Lysophosphatidylcholines"
#  [29] "Lysophosphatidylcholines"         "Lysophosphatidylcholines"
#  [31] "Lysophosphatidylcholines"         "Lysophosphatidylcholines"
#  [33] "Lysophosphatidylcholines"         "Lysophosphatidylcholines"
#  [35] "Lysophosphatidylcholines"         "Lysophosphatidylcholines"
#  [37] "Oxidized Phosphatidylcholines"    "Oxidized Phosphatidylcholines"
#  [39] "Oxydized Sphingomyelins"          "Phosphatidylcholine ethers"
#  [41] "Phosphatidylcholine ethers"       "Phosphatidylcholine ethers"
#  [43] "Phosphatidylcholine ethers"       "Phosphatidylcholine ethers"
#  [45] "Phosphatidylcholine ethers"       "Phosphatidylcholine ethers"
#  [47] "Phosphatidylcholine ethers"       "Phosphatidylcholine ethers"
#  [49] "Phosphatidylcholine ethers"       "Phosphatidylcholine ethers"
#  [51] "Phosphatidylcholine ethers"       "Phosphatidylcholine ethers"
#  [53] "Phosphatidylcholine ethers"       "Phosphatidylcholine ethers"
#  [55] "Phosphatidylcholine ethers"       "Phosphatidylcholine ethers"
#  [57] "Phosphatidylcholine ethers"       "Phosphatidylcholine ethers"
#  [59] "Phosphatidylcholine ethers"       "Phosphatidylcholine ethers"
#  [61] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [63] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [65] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [67] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [69] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [71] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [73] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [75] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [77] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [79] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [81] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [83] "Phosphatidylcholines"             "Phosphatidylcholines"
#  [85] "Phosphatidylethanolamines"        "Phosphatidylethanolamines"
#  [87] "Phosphatidylethanolamines"        "Phosphatidylethanolamines"
#  [89] "Phosphatidylethanolamines"        "Phosphatidylethanolamines ethers"
#  [91] "Phosphatidylethanolamines ethers" "Phosphatidylethanolamines ethers"
#  [93] "Phosphatidylethanolamines ethers" "Sphingomyelins"
#  [95] "Sphingomyelins"                   "Sphingomyelins"
#  [97] "Sphingomyelins"                   "Sphingomyelins"
#  [99] "Sphingomyelins"                   "Sphingomyelins"
# [101] "Sphingomyelins"                   "Sphingomyelins"
# [103] "Sphingomyelins"                   "Sphingomyelins"
# [105] "Sphingomyelins"                   "Sphingomyelins"
# [107] "Sphingomyelins"                   "Sphingomyelins"
# [109] "Sphingomyelins"                   "Sphingomyelins"
# [111] "Diglycerides"                     "Diglycerides"
# [113] "Epoxy triglycerides"              "Epoxy triglycerides"
# [115] "Triglycerides"                    "Triglycerides"
# [117] "Triglycerides"                    "Triglycerides"
# [119] "Triglycerides"                    "Triglycerides"
# [121] "Triglycerides"                    "Triglycerides"
# [123] "Triglycerides"                    "Triglycerides"
# [125] "Triglycerides"                    "Triglycerides"
# [127] "Triglycerides"                    "Triglycerides"
# [129] "Triglycerides"                    "Triglycerides"
# [131] "Triglycerides"                    "Triglycerides"
# [133] "Triglycerides"                    "Triglycerides"
# [135] "Triglycerides"                    "Triglycerides"
# [137] "Triglycerides"                    "Triglycerides"
# [139] "Triglycerides"                    "Triglycerides"
# [141] "Triglycerides"                    "Triglycerides"
# [143] "Triglycerides"                    "Triglycerides"
# [145] "Triglycerides"                    "Triglycerides"
# [147] "Triglycerides"                    "Triglycerides"
# [149] "Triglycerides"                    "Triglycerides"
# [151] "Triglycerides"                    "Triglycerides"
# [153] "Triglycerides"                    "Triglycerides"
# [155] "Triglycerides"                    "Triglycerides"
# [157] "Triglycerides"                    "Triglycerides"
# [159] "Triglycerides"                    "Triglycerides"
# [161] "Triglycerides"

# %%
library(RColorBrewer)

n <- nlevels(as.factor(importance$lipid_class))
qual_col_pals = brewer.pal.info[brewer.pal.info$category == 'qual',]
col_vector = unlist(mapply(brewer.pal, qual_col_pals$maxcolors, rownames(qual_col_pals)))
col_vector = sample(col_vector, n)

# Map the color to cylinders
my_color <- col_vector[as.numeric(as.factor(importance[rownames(mat),'lipid_class']))]

# %%
names(col_vector) = unique(importance[rownames(mat),'lipid_class'])

# %%
unique(importance[rownames(mat),'lipid_class'])
# Out:
#  [1] "Acylcarnitines"                   "Ceramides"
#  [3] "Cholesteryl esters"               "Lysophosphatidylcholine ethers"
#  [5] "Lysophosphatidylcholines"         "Oxidized Phosphatidylcholines"
#  [7] "Oxydized Sphingomyelins"          "Phosphatidylcholine ethers"
#  [9] "Phosphatidylcholines"             "Phosphatidylethanolamines"
# [11] "Phosphatidylethanolamines ethers" "Sphingomyelins"
# [13] "Diglycerides"                     "Epoxy triglycerides"
# [15] "Triglycerides"

# %%
importance = read.csv('../data/var_importance.b1.csv')

# %%
options(repr.plot.width = 15, repr.plot.height = 15)
mat <- cor(scaled_df)
mat[mat<0.6] <- 0
network <- graph_from_adjacency_matrix(abs(mat), weighted=T, mode="undirected", diag=F)

c_scale <- colorRamp(rev(c('red','darkorange1','yellow','grey')))

E(network)$color = apply(c_scale(E(network)$weight), 1, function(x) rgb(x[1]/255,x[2]/255,x[3]/255) )

plot(network,

    # === vertex
    vertex.color=my_color,          # Node color
    vertex.frame.color = "black",                 # Node border color
    vertex.shape="circle",                        # One of “none”, “circle”, “square”, “csquare”, “rectangle” “crectangle”, “vrectangle”, “pie”, “raster”, or “sphere”
    vertex.size=5,                               # Size of the node (default is 15)
    vertex.size2=NA,                              # The second size of the node (e.g. for a rectangle)

    # === vertex label
    vertex.label.color="white",
    vertex.label.family="Times",  
     # Font family of the label (e.g.“Times”, “Helvetica”)
    vertex.label.font=2,                          # Font: 1 plain, 2 bold, 3, italic, 4 bold italic, 5 symbol
    vertex.label.cex=1,                           # Font size (multiplication factor, device-dependent)
    vertex.label.dist=0,                          # Distance between the label and the vertex
    vertex.label.degree=0 ,                       # The position of the label in relation to the vertex (use pi)

    # === Edge
    edge.width=scale(edge.betweenness(network)),                                 # Edge width, defaults to 1
    edge.arrow.size=1,                            # Arrow size, defaults to 1
    edge.arrow.width=1,                           # Arrow width, defaults to 1
    edge.lty="solid",                             # Line type, could be 0 or “blank”, 1 or “solid”, 2 or “dashed”, 3 or “dotted”, 4 or “dotdash”, 5 or “longdash”, 6 or “twodash”
    edge.curved=0.3    ,                          # Edge curvature, range 0-1 (FALSE sets it to 0, TRUE to 0.5)
    )
# Out:
# Plot with title “”
